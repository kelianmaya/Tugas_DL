# %% [markdown]
# <a href="https://colab.research.google.com/github/kelianmaya/Tugas_DL/blob/main/Tugas_DL%20/TugasDLTM4/splitdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'nnfl-cnn-lab2:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-competitions-data%2Fkaggle-v2%2F19704%2F1064412%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240501%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240501T081241Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading nnfl-cnn-lab2, 318864853 bytes compressed
# [==================================================] 318864853 bytes downloaded
# Downloaded and uncompressed: nnfl-cnn-lab2
# Data source import complete.

# %%
import os

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from keras.layers import Input
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from PIL import Image

from keras.models import Sequential,Model
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from keras.optimizers import RMSprop
from keras.initializers import glorot_uniform

# %%
df = pd.read_csv('/kaggle/input/nnfl-cnn-lab2/upload/train_set.csv')

# %%
df.head()
# Out:
#   image_name  label
# 0      0.jpg      0
# 1      1.jpg      4
# 2      2.jpg      5
# 3      4.jpg      0
# 4      7.jpg      4

# %%
df['label'] = df['label'].astype(str)
df.dtypes
# Out:
# image_name    object
# label         object
# dtype: object

# %%
df['label'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
filenames = os.listdir('/kaggle/input/nnfl-cnn-lab2/upload/train_images/train_images/')
sample = random.choice(filenames)
image = load_img('/kaggle/input/nnfl-cnn-lab2/upload/train_images/train_images/'+sample)
plt.imshow(image)
print(image.size)
# Out:
# (150, 150)

# %%
IMAGE_HEIGHT = 150
IMAGE_WIDTH = 150
IMAGE_CHANNELS = 3
IMAGE_SIZE = (IMAGE_HEIGHT,IMAGE_WIDTH)
batch_size = 256

# %%
def identity_block(X, f, filters, stage, block):

    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. You'll need this later to add back to the main path.
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = Activation('relu')(X)
    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = Activation('relu')(X)
    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)


    return X
def convolutional_block(X, f, filters, stage, block, s = 2):

    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = Activation('relu')(X)
    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = Activation('relu')(X)
    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)

    ##### SHORTCUT PATH #### (≈2 lines)
    X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    return X

def ResNet50(input_shape=(64, 64, 3), classes=6):

    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(128, (3, 3), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = convolutional_block(X, f=3, filters=[128, 128, 51], stage=2, block='a', s=1)
    X = AveragePooling2D((2,2), name="avg_pool")(X)

    ### END CODE HERE ###

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)


    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model
model = ResNet50(input_shape = (150, 150, 3), classes = 6)
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 156, 156, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1 (Conv2D)              (None, 77, 77, 128)          3584      ['zero_padding2d[0][0]']
#
#  activation (Activation)     (None, 77, 77, 128)          0         ['conv1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 38, 38, 128)          0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv2D)     (None, 38, 38, 128)          16512     ['max_pooling2d[0][0]']
#
#  activation_1 (Activation)   (None, 38, 38, 128)          0         ['res2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)     (None, 38, 38, 128)          147584    ['activation_1[0][0]']
#
#  activation_2 (Activation)   (None, 38, 38, 128)          0         ['res2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)     (None, 38, 38, 51)           6579      ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)      (None, 38, 38, 51)           6579      ['max_pooling2d[0][0]']
#
#  add (Add)                   (None, 38, 38, 51)           0         ['res2a_branch2c[0][0]',
#                                                                      'res2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 38, 38, 51)           0         ['add[0][0]']
#
#  avg_pool (AveragePooling2D  (None, 19, 19, 51)           0         ['activation_3[0][0]']
#  )
#
#  flatten (Flatten)           (None, 18411)                0         ['avg_pool[0][0]']
#
#  fc6 (Dense)                 (None, 6)                    110472    ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 291310 (1.11 MB)
# Trainable params: 291310 (1.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
earlystop = EarlyStopping(patience=60)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=2,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00002)
Checkpoint = ModelCheckpoint('temp.h5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
callbacks = [earlystop, learning_rate_reduction,Checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['label'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
validate_df['label'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
print(total_train, total_validate)
# Out:
# 11227 2807

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "/kaggle/input/nnfl-cnn-lab2/upload/train_images/train_images/",
    x_col='image_name',
    y_col='label',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 11227 validated image filenames belonging to 6 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    "/kaggle/input/nnfl-cnn-lab2/upload/train_images/train_images/",
    x_col='image_name',
    y_col='label',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2807 validated image filenames belonging to 6 classes.

# %%
epochs = 50

# Assuming you have defined train_generator and validation_generator correctly
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    batch_size =32,
    validation_steps=total_validate // batch_size,
    steps_per_epoch=total_train // batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.8262
# Epoch 1: val_accuracy improved from -inf to 0.82695, saving model to temp.h5
# 43/43 [==============================] - 80s 2s/step - loss: 0.4914 - accuracy: 0.8262 - val_loss: 0.4910 - val_accuracy: 0.8270 - lr: 1.0000e-05
# Epoch 2/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.8259
# Epoch 2: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 70s 2s/step - loss: 0.4887 - accuracy: 0.8259 - val_loss: 0.5025 - val_accuracy: 0.8223 - lr: 1.0000e-05
# Epoch 3/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4903 - accuracy: 0.8256
# Epoch 3: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 74s 2s/step - loss: 0.4903 - accuracy: 0.8256 - val_loss: 0.4962 - val_accuracy: 0.8234 - lr: 1.0000e-05
# Epoch 4/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8211
# Epoch 4: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 74s 2s/step - loss: 0.4890 - accuracy: 0.8211 - val_loss: 0.4861 - val_accuracy: 0.8258 - lr: 1.0000e-05
# Epoch 5/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.8233
# Epoch 5: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 74s 2s/step - loss: 0.4923 - accuracy: 0.8233 - val_loss: 0.4919 - val_accuracy: 0.8246 - lr: 1.0000e-05
# Epoch 6/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4841 - accuracy: 0.8277
# Epoch 6: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 74s 2s/step - loss: 0.4841 - accuracy: 0.8277 - val_loss: 0.4961 - val_accuracy: 0.8211 - lr: 1.0000e-05
# Epoch 7/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.8210
# Epoch 7: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 75s 2s/step - loss: 0.4895 - accuracy: 0.8210 - val_loss: 0.4909 - val_accuracy: 0.8230 - lr: 1.0000e-05
# Epoch 8/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4891 - accuracy: 0.8232
# Epoch 8: val_accuracy did not improve from 0.82695
# 43/43 [==============================] - 75s 2s/step - loss: 0.4891 - accuracy: 0.8232 - val_loss: 0.4994 - val_accuracy: 0.8195 - lr: 1.0000e-05
# Epoch 9/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.8265
# Epoch 9: val_accuracy improved from 0.82695 to 0.82773, saving model to temp.h5
# 43/43 [==============================] - 74s 2s/step - loss: 0.4818 - accuracy: 0.8265 - val_loss: 0.4853 - val_accuracy: 0.8277 - lr: 1.0000e-05
# Epoch 10/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8216
# Epoch 10: val_accuracy did not improve from 0.82773
# 43/43 [==============================] - 74s 2s/step - loss: 0.4894 - accuracy: 0.8216 - val_loss: 0.4925 - val_accuracy: 0.8230 - lr: 1.0000e-05
# Epoch 11/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.8248
# Epoch 11: val_accuracy improved from 0.82773 to 0.82969, saving model to temp.h5
# 43/43 [==============================] - 72s 2s/step - loss: 0.4893 - accuracy: 0.8248 - val_loss: 0.4914 - val_accuracy: 0.8297 - lr: 1.0000e-05
# Epoch 12/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.8233
# Epoch 12: val_accuracy did not improve from 0.82969
# 43/43 [==============================] - 72s 2s/step - loss: 0.4874 - accuracy: 0.8233 - val_loss: 0.4899 - val_accuracy: 0.8254 - lr: 1.0000e-05
# Epoch 13/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4778 - accuracy: 0.8296
# Epoch 13: val_accuracy did not improve from 0.82969
# 43/43 [==============================] - 72s 2s/step - loss: 0.4778 - accuracy: 0.8296 - val_loss: 0.4984 - val_accuracy: 0.8230 - lr: 1.0000e-05
# Epoch 14/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4829 - accuracy: 0.8266
# Epoch 14: val_accuracy did not improve from 0.82969
# 43/43 [==============================] - 72s 2s/step - loss: 0.4829 - accuracy: 0.8266 - val_loss: 0.4904 - val_accuracy: 0.8285 - lr: 1.0000e-05
# Epoch 15/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4868 - accuracy: 0.8253
# Epoch 15: val_accuracy did not improve from 0.82969
# 43/43 [==============================] - 73s 2s/step - loss: 0.4868 - accuracy: 0.8253 - val_loss: 0.4791 - val_accuracy: 0.8250 - lr: 1.0000e-05
# Epoch 16/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4855 - accuracy: 0.8281
# Epoch 16: val_accuracy did not improve from 0.82969
# 43/43 [==============================] - 74s 2s/step - loss: 0.4855 - accuracy: 0.8281 - val_loss: 0.4835 - val_accuracy: 0.8254 - lr: 1.0000e-05
# Epoch 17/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.8257
# Epoch 17: val_accuracy did not improve from 0.82969
# 43/43 [==============================] - 72s 2s/step - loss: 0.4874 - accuracy: 0.8257 - val_loss: 0.4907 - val_accuracy: 0.8285 - lr: 1.0000e-05
# Epoch 18/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.8286
# Epoch 18: val_accuracy improved from 0.82969 to 0.83008, saving model to temp.h5
# 43/43 [==============================] - 72s 2s/step - loss: 0.4899 - accuracy: 0.8286 - val_loss: 0.4867 - val_accuracy: 0.8301 - lr: 1.0000e-05
# Epoch 19/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4960 - accuracy: 0.8237
# Epoch 19: val_accuracy did not improve from 0.83008
# 43/43 [==============================] - 73s 2s/step - loss: 0.4960 - accuracy: 0.8237 - val_loss: 0.4919 - val_accuracy: 0.8293 - lr: 1.0000e-05
# Epoch 20/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.8265
# Epoch 20: val_accuracy did not improve from 0.83008
# 43/43 [==============================] - 73s 2s/step - loss: 0.4854 - accuracy: 0.8265 - val_loss: 0.4949 - val_accuracy: 0.8270 - lr: 1.0000e-05
# Epoch 21/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.8246
# Epoch 21: val_accuracy did not improve from 0.83008
# 43/43 [==============================] - 74s 2s/step - loss: 0.4847 - accuracy: 0.8246 - val_loss: 0.4894 - val_accuracy: 0.8262 - lr: 1.0000e-05
# Epoch 22/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.8249
# Epoch 22: val_accuracy did not improve from 0.83008
# 43/43 [==============================] - 73s 2s/step - loss: 0.4792 - accuracy: 0.8249 - val_loss: 0.4872 - val_accuracy: 0.8270 - lr: 1.0000e-05
# Epoch 23/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4832 - accuracy: 0.8293
# Epoch 23: val_accuracy did not improve from 0.83008
# 43/43 [==============================] - 73s 2s/step - loss: 0.4832 - accuracy: 0.8293 - val_loss: 0.4901 - val_accuracy: 0.8297 - lr: 1.0000e-05
# Epoch 24/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.8230
# Epoch 24: val_accuracy improved from 0.83008 to 0.83281, saving model to temp.h5
# 43/43 [==============================] - 72s 2s/step - loss: 0.4848 - accuracy: 0.8230 - val_loss: 0.4753 - val_accuracy: 0.8328 - lr: 1.0000e-05
# Epoch 25/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.8244
# Epoch 25: val_accuracy did not improve from 0.83281
# 43/43 [==============================] - 73s 2s/step - loss: 0.4879 - accuracy: 0.8244 - val_loss: 0.4901 - val_accuracy: 0.8273 - lr: 1.0000e-05
# Epoch 26/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4845 - accuracy: 0.8268
# Epoch 26: val_accuracy did not improve from 0.83281
# 43/43 [==============================] - 72s 2s/step - loss: 0.4845 - accuracy: 0.8268 - val_loss: 0.4779 - val_accuracy: 0.8316 - lr: 1.0000e-05
# Epoch 27/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.8309
# Epoch 27: val_accuracy did not improve from 0.83281
# 43/43 [==============================] - 74s 2s/step - loss: 0.4850 - accuracy: 0.8309 - val_loss: 0.4918 - val_accuracy: 0.8262 - lr: 1.0000e-05
# Epoch 28/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.8262
# Epoch 28: val_accuracy improved from 0.83281 to 0.83398, saving model to temp.h5
# 43/43 [==============================] - 71s 2s/step - loss: 0.4872 - accuracy: 0.8262 - val_loss: 0.4802 - val_accuracy: 0.8340 - lr: 1.0000e-05
# Epoch 29/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.8295
# Epoch 29: val_accuracy did not improve from 0.83398
# 43/43 [==============================] - 72s 2s/step - loss: 0.4835 - accuracy: 0.8295 - val_loss: 0.4793 - val_accuracy: 0.8324 - lr: 1.0000e-05
# Epoch 30/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.8284
# Epoch 30: val_accuracy improved from 0.83398 to 0.83516, saving model to temp.h5
# 43/43 [==============================] - 72s 2s/step - loss: 0.4848 - accuracy: 0.8284 - val_loss: 0.4860 - val_accuracy: 0.8352 - lr: 1.0000e-05
# Epoch 31/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.8281
# Epoch 31: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4810 - accuracy: 0.8281 - val_loss: 0.4841 - val_accuracy: 0.8309 - lr: 1.0000e-05
# Epoch 32/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.8297
# Epoch 32: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4792 - accuracy: 0.8297 - val_loss: 0.4810 - val_accuracy: 0.8320 - lr: 1.0000e-05
# Epoch 33/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.8269
# Epoch 33: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4848 - accuracy: 0.8269 - val_loss: 0.4855 - val_accuracy: 0.8309 - lr: 1.0000e-05
# Epoch 34/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.8259
# Epoch 34: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 71s 2s/step - loss: 0.4858 - accuracy: 0.8259 - val_loss: 0.4961 - val_accuracy: 0.8250 - lr: 1.0000e-05
# Epoch 35/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.8296
# Epoch 35: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 71s 2s/step - loss: 0.4781 - accuracy: 0.8296 - val_loss: 0.4719 - val_accuracy: 0.8320 - lr: 1.0000e-05
# Epoch 36/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.8287
# Epoch 36: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4797 - accuracy: 0.8287 - val_loss: 0.4837 - val_accuracy: 0.8297 - lr: 1.0000e-05
# Epoch 37/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.8247
# Epoch 37: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4853 - accuracy: 0.8247 - val_loss: 0.4825 - val_accuracy: 0.8273 - lr: 1.0000e-05
# Epoch 38/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4741 - accuracy: 0.8326
# Epoch 38: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 71s 2s/step - loss: 0.4741 - accuracy: 0.8326 - val_loss: 0.4917 - val_accuracy: 0.8250 - lr: 1.0000e-05
# Epoch 39/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.8296
# Epoch 39: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 69s 2s/step - loss: 0.4847 - accuracy: 0.8296 - val_loss: 0.4824 - val_accuracy: 0.8336 - lr: 1.0000e-05
# Epoch 40/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4796 - accuracy: 0.8296
# Epoch 40: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 71s 2s/step - loss: 0.4796 - accuracy: 0.8296 - val_loss: 0.4885 - val_accuracy: 0.8293 - lr: 1.0000e-05
# Epoch 41/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8288
# Epoch 41: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4803 - accuracy: 0.8288 - val_loss: 0.4869 - val_accuracy: 0.8313 - lr: 1.0000e-05
# Epoch 42/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4766 - accuracy: 0.8276
# Epoch 42: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4766 - accuracy: 0.8276 - val_loss: 0.4789 - val_accuracy: 0.8332 - lr: 1.0000e-05
# Epoch 43/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.8338
# Epoch 43: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4739 - accuracy: 0.8338 - val_loss: 0.4869 - val_accuracy: 0.8289 - lr: 1.0000e-05
# Epoch 44/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4845 - accuracy: 0.8283
# Epoch 44: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 72s 2s/step - loss: 0.4845 - accuracy: 0.8283 - val_loss: 0.4895 - val_accuracy: 0.8281 - lr: 1.0000e-05
# Epoch 45/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4764 - accuracy: 0.8291
# Epoch 45: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4764 - accuracy: 0.8291 - val_loss: 0.4819 - val_accuracy: 0.8320 - lr: 1.0000e-05
# Epoch 46/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.8265
# Epoch 46: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 71s 2s/step - loss: 0.4818 - accuracy: 0.8265 - val_loss: 0.4821 - val_accuracy: 0.8297 - lr: 1.0000e-05
# Epoch 47/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4743 - accuracy: 0.8304
# Epoch 47: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 68s 2s/step - loss: 0.4743 - accuracy: 0.8304 - val_loss: 0.4861 - val_accuracy: 0.8301 - lr: 1.0000e-05
# Epoch 48/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.8305
# Epoch 48: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 72s 2s/step - loss: 0.4757 - accuracy: 0.8305 - val_loss: 0.4928 - val_accuracy: 0.8281 - lr: 1.0000e-05
# Epoch 49/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.8296
# Epoch 49: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 70s 2s/step - loss: 0.4777 - accuracy: 0.8296 - val_loss: 0.4834 - val_accuracy: 0.8309 - lr: 1.0000e-05
# Epoch 50/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.8296
# Epoch 50: val_accuracy did not improve from 0.83516
# 43/43 [==============================] - 71s 2s/step - loss: 0.4710 - accuracy: 0.8296 - val_loss: 0.4942 - val_accuracy: 0.8277 - lr: 1.0000e-05

# %%
model.load_weights('temp.h5')

# %%
model.save_weights("model.h5")

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
validation_generator = validation_datagen.flow_from_dataframe(
    pd.DataFrame(validate_df),
    "/kaggle/input/nnfl-cnn-lab2/upload/train_images/train_images/",
    x_col='image_name',
    y_col='label',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle = False
)
y_pred = [np.argmax(a) for a in (model.predict_generator(validation_generator))]
# Out:
# Found 2807 validated image filenames belonging to 6 classes.
# <ipython-input-45-d37e3074760d>:11: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = [np.argmax(a) for a in (model.predict_generator(validation_generator))]

# %%
f1_score(y_pred,validate_df['label'].astype(int), average = 'micro')
# Out:
# 0.8297114356964731

# %%
confusion_matrix(y_pred,validate_df['label'].astype(int))
# Out:
# array([[360,   5,  12,   9,  13,  55],
#        [ 10, 448,   8,   6,   3,  20],
#        [  2,   0, 336,  51,  17,   1],
#        [  4,   4,  67, 395,  31,   3],
#        [  9,   2,  29,  36, 403,   4],
#        [ 52,  13,   3,   1,   8, 387]])

# %%
test_df = pd.read_csv('/kaggle/input/nnfl-cnn-lab2/upload/sample_submission.csv')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    test_df,
    "/kaggle/input/nnfl-cnn-lab2/upload/test_images/test_images/",
    x_col='image_name',
    y_col=None,
    target_size=IMAGE_SIZE,
    class_mode=None,
    batch_size=batch_size,
    shuffle = False
)
nb_samples = test_df.shape[0]
# Out:
# Found 7301 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# <ipython-input-50-52619fd72ccc>:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['label'] = np.argmax(predict, axis = -1)

# %%
test_df.head()
# Out:
#   image_name  label
# 0      3.jpg      5
# 1      5.jpg      0
# 2      6.jpg      4
# 3     11.jpg      4
# 4     14.jpg      5

# %%
test_df['label'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
submission_df = test_df.copy()
submission_df['image_name'] = submission_df['image_name']
submission_df['label'] = submission_df['label']
submission_df.image_name = submission_df.image_name.apply(str)
#submission_df.drop(['filename', 'category'], axis=1, inplace=True)
print(submission_df.head())
submission_df.to_csv('submission.csv', index=False)
# Out:
#   image_name  label
# 0      3.jpg      5
# 1      5.jpg      0
# 2      6.jpg      4
# 3     11.jpg      4
# 4     14.jpg      5

# %%
from IPython.display import HTML
import pandas as pd
import numpy as np
import base64
def create_download_link(df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)
create_download_link(submission_df)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
